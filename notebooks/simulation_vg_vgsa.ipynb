# %%
# necessary to import from filtering

# %%
cd ..
# Out:
# /Users/Mason/Desktop/Columbia/computational-methods-in-finance/cfinance-filtering

# %%
import numpy as np
from importlib import reload
import matplotlib.pyplot as plt

# %%
from filtering.utils import simulate as sim

# %% [markdown]
# # VG Simulation

# %%
S0 = 100
mu = 0.01
theta = -0.15
sigma = 0.25
nu = 0.15

T = 7
N = 365 * 2
dt = T/N

# %%
vg_params = [mu, theta, sigma, nu]
vg_params
# Out:
# [0.01, -0.15, 0.25, 0.15]

# %%
reload(sim)
# Out:
# <module 'filtering.utils.simulate' from '/Users/Mason/Desktop/Columbia/computational-methods-in-finance/cfinance-filtering/filtering/utils/simulate.py'>

# %%
y, jumps = sim.simulate_vg(vg_params, S0, N=N, dt=dt)

# %%
plt.plot(y)
plt.show()

# %%
plt.plot(jumps)
plt.show()

# %% [markdown]
# # VGSA

# %%
S0 = 100
mu = -0.0451
kappa = 3.5 # mean reversion rate
theta = -0.1762
sigma = 0.1308
nu = 0.0726
eta = 6.3 # long-term rate of change
lda = 8.5 # time change vol

T = 1
N = 500
dt = T/N

# %%
vgsa_params = [mu, kappa, theta, sigma, nu, eta, lda]

# %%
y, jumps = sim.simulate_vgsa(vgsa_params, S0, N=N, dt=dt)

# %%
plt.plot(y)
plt.show()

# %%
plt.plot(jumps)
plt.show()

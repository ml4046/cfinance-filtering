# %%
cd ..
# Out:
# /Users/Mason/Desktop/Columbia/computational-methods-in-finance/cfinance-filtering

# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from scipy.stats import norm
from matplotlib import cm
from importlib import reload
from scipy.optimize import fmin, minimize

# %%
from filtering.utils import simulate as sim
from filtering.filtering import kf

# %% [markdown]
# # Simulating Data

# %%
# S0 = 149.54
S0 = 100
# r = 0.0245
r = 0.2
q = 0
N = 1000

# %%
true_params = [r, 2.2, 0.01, 0.3, -0.6, 0.02]
init_params = [0.6, 1.1, 0.03, 0.35, -0.4, 0.035]

# %%
y = sim.simulate_heston_state(true_params, S0, N=N)
obs = np.array(y[0,:])[0]

# %%
ukf = kf.UKFHeston(obs, is_log=True)

# %%
x_preds, y_preds = ukf.filter(obs, init_params)

# %% [markdown]
# ### simulate path and ekf generated path

# %%
years = np.arange(y.shape[-1]-1) * (1/250)
plt.plot(years, y[0,1:].T, 'b--')
plt.title('simulate path')
plt.xlabel('years')
plt.show()

# %%
print('before param. estimation')
print("# neg vol:", sum(y[1,:].T<0))
plt.plot(years[:], np.array(y[1,1:])[0], 'b-')
plt.plot(years[:], x_preds[1:], 'r-')
plt.title('daily vol. true (b) vs. model (r)')
plt.xlabel('years')
plt.show()
# Out:
# before param. estimation
# # neg vol: [[45]]

# %% [markdown]
# # Filtering

# %% [markdown]
# ## Optimize

# %%
def param_select(params1, params2, n_alphas=1000):
    params1 = np.array(params1)
    params2 = np.array(params2)
    alphas = np.linspace(0, 1, n_alphas)
    params = [a*params1+(1-a)*params2 for a in alphas]
    objs = [wrap_heston_obj(p, *args) for p in params]
    return objs

# %%
print("Init params: {}".format(init_params))
print("True Params: {}".format(true_params))
# Out:
# Init params: [0.6, 1.1, 0.03, 0.35, -0.4, 0.035]
# True Params: [0.2, 2.2, 0.01, 0.3, -0.6, 0.02]

# %%
xopt = ukf.optimize(init_params, maxiter=100)
# Out:
# [0.6, 1.1, 0.03, 0.35, -0.4, 0.035]
# i: 1
# x_i: [ 0.54      1.1275    0.03075   0.35875  -0.41      0.035875]
# f_i: -8215.491150038397
# i: 2
# x_i: [ 0.54      1.1275    0.03075   0.35875  -0.41      0.035875]
# f_i: -8215.491150038397
# i: 3
# x_i: [ 0.54      1.1275    0.03075   0.35875  -0.41      0.035875]
# f_i: -8215.491150038397
# i: 4
# x_i: [ 0.54666667  1.17333333  0.02825     0.34611111 -0.40333333  0.03733333]
# f_i: -8267.919148929364
# i: 5
# x_i: [ 0.54666667  1.17333333  0.02825     0.34611111 -0.40333333  0.03733333]
# f_i: -8267.919148929364
# i: 6
# x_i: [ 0.49333333  1.24666667  0.0305      0.34222222 -0.40666667  0.037625  ]
# f_i: -8351.801338666304
# i: 7
# x_i: [ 0.49333333  1.24666667  0.0305      0.34222222 -0.40666667  0.037625  ]
# f_i: -8351.801338666304
# i: 8
#  -3.85823301e-01  5.09432566e-02]
# f_i: -11533.772484540472
# i: 89
# x_i: [ 8.66760432e-03  1.70103345e+00  1.25997672e-03  5.00655104e-01
#  -3.85823301e-01  5.09432566e-02]
# f_i: -11533.772484540472
# i: 90
# x_i: [ 1.11318000e-02  1.70449805e+00  7.78270575e-04  4.99539134e-01
#  -3.85132773e-01  5.11481204e-02]
# f_i: -11534.11608983263
# i: 91
# x_i: [ 1.11318000e-02  1.70449805e+00  7.78270575e-04  4.99539134e-01
#  -3.85132773e-01  5.11481204e-02]
# f_i: -11534.11608983263
# i: 92
# x_i: [ 1.11318000e-02  1.70449805e+00  7.78270575e-04  4.99539134e-01
#  -3.85132773e-01  5.11481204e-02]
# f_i: -11534.11608983263
# i: 93
# x_i: [ 1.16002343e-02  1.69826442e+00  8.75194454e-04  5.01538703e-01
#  -3.86246767e-01  5.10900778e-02]
# f_i: -11534.315686102469
# i: 94
# x_i: [ 1.16002343e-02  1.69826442e+00  8.75194454e-04  5.01538703e-01
#  -3.86246767e-01  5.10900778e-02]
# f_i: -11534.315686102469
# i: 95
# x_i: [ 7.85207137e-03  1.70905718e+00  8.50087033e-04  5.01089028e-01
#  -3.84390088e-01  5.09189553e-02]
# f_i: -11534.817637393595
# i: 96
# x_i: [ 8.09631146e-03  1.71059809e+00  8.31853585e-04  5.01131139e-01
#  -3.84226909e-01  5.09254027e-02]
# f_i: -11535.295991622606
# i: 97
# x_i: [ 9.48176477e-03  1.70339874e+00  7.16082413e-04  5.02614049e-01
#  -3.85000159e-01  5.09918932e-02]
# f_i: -11535.563240038467
# i: 98
# x_i: [ 1.11242129e-02  1.70302900e+00  8.41864986e-04  5.04092860e-01
#  -3.84239594e-01  5.07372201e-02]
# f_i: -11538.308883545033
# i: 99
# x_i: [ 9.27433506e-03  1.70292051e+00  1.03776778e-03  5.01161295e-01
#  -3.85348008e-01  5.09559341e-02]
# f_i: -11540.361724940516
# Warning: Maximum number of iterations has been exceeded.

# %% [markdown]
# # Plot Results

# %%
x_preds, y_preds = ukf.filter(obs, xopt)

# %%
print(xopt)
print(true_params)
# Out:
# [ 9.27433506e-03  1.70292051e+00  1.03776778e-03  5.01161295e-01
#  -3.85348008e-01  5.09559341e-02]
# [0.2, 2.2, 0.01, 0.3, -0.6, 0.02]

# %%
years = np.arange(y.shape[-1]) * (1/250)
plt.plot(years[:], y[0,:].T, 'b--')
plt.plot(years[:], y_preds[:], 'r--')
plt.title('true path (b) vs. model path (r)')
plt.xlabel('years')
plt.show()

# %%
print("# neg vol:", sum(y[1,:].T<0))
plt.plot(years[:], np.array(y[1,:])[0], 'b-')
plt.plot(years[:], x_preds[:], 'r-')
plt.title('daily vol. true (b) vs. model (r)')
plt.xlabel('years')
plt.show()
# Out:
# # neg vol: [[45]]
